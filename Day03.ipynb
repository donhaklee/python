# %%
# 문제 2-1] Linux 의 수업료가 500,000원이고 Windows 수업료는  400,000원이다. 
# 9월 수강생이 Linux를 30명 수강하고 Windows는  20명 수강한다. 
# 월 수업료 총액을 계산하는 프로그램을 작성하세요.
Linux = 500000
Windows = 400000
Total = (Linux * 30) + (Windows * 20)
print('월 수업료 총액 : {:,.2f}'.format(Total))
# Out:
# 월 수업료 총액 : 23,000,000.00

# %%
# 문제 2-2] 문제 2-1에서 구한 수업료 총액에서  Linux과 Windows의 수업료가 
# 각각 5%, 10% Discount한 경우에 손실액을 구하는 프로그램을 작성하세요.
Linux = 500000
Windows = 400000
Total = (Linux * 30) + (Windows * 20)
Discount = (Linux * 30 * 0.05) + (Windows * 20 * 0.1)
B = Total - Discount
print('손실액은 {:,.2f}'.format(Total - B))
# Out:
# 손실액은 1,550,000.00

# %%
# 문제 2-3] 우리나라는 섭씨 온도를 사용하는 반면 
# 미국과 유럽은 화씨 온도를 주로 사용합니다. 
# 화씨 온도(F)를 섭씨 온도(C)로 변환할 때는 다음과 같은 공식을 사용합니다. 
# 이 공식을 사용해 화씨 온도가 50일 때의 섭씨 온도를 계산해 보세요.
# C = (F-32)/1.8

F = 50
C = (F-32)/1.8
print('섭씨 온도는 {}입니다.'.format(C))
# Out:
# 섭씨 온도는 10.0입니다.

# %%
# 문제 2-4] 화면에 "Linux"를 10번 출력하는 프로그램을 작성하세요.
print('Linux\n' * 10)
# Out:
# Linux
# Linux
# Linux
# Linux
# Linux
# Linux
# Linux
# Linux
# Linux
# Linux

# %%
# 문제 2-5] 다음 형식과 같이 이름, 생년월일, 주민등록번호를 
# 출력하는 프로그램을 작성해 보세요. 
# 이름: 파이썬 생년월일: 2014년 12월 12일 주민등록번호: 20141212-1623210
name = '파이썬'
birth = '2014년 12월 12일'
jumin = '20141212-1623210'
print('이름: {} 생년월일: {} 주민등록번호: {}'.format(name,birth,jumin))

jumin = '20141212-1623210'
year = jumin[0:4]
month = jumin[4:6]
day = jumin[6:8]
name = '파이썬'
print(f'이름: {name} 생년월일: {year}년,{month}월,{day}일 주민등록번호: {jumin}')
# Out:
# 이름: 파이썬 생년월일: 2014년 12월 12일 주민등록번호: 20141212-1623210
# 이름: 파이썬 생년월일: 2014년,12월,12일 주민등록번호: 20141212-1623210

# %%
# 문제 2-6] s라는 변수에 'Linux is not Unix'라는 문자열이 바인딩돼 있다고 했을 때 
# 문자열의 슬라이싱 기능과 연결하기를 이용해 
# s의 값을 'Unix is not Linux'으로 변경해 보세요.
s = 'Linux is not Unix'
s1 = (s[0:5])
s1 = (s[13:17])
s11 = (s1.replace('Linux','Unix'))
s22 = (s1.replace('Unix','Linux'))
print(f'{s11} is not {s22}')

# OR

str8 = 'Linux is not Unix'
str8 = str8.split()
str9,str10 = str8[3],str8[0]
print(f'{str9} is not {str10}')
# Out:
# Unix is not Linux
# Unix is not Linux

# %%
# 문제 2-7] x라는 변수에 'abcdef'라는 문자열이 바인딩돼 있다고 했을 때 
# x의 값을 'bcdefa'로 변경해 보세요.
str1 = 'abcdef'
table = str.maketrans('abcdef','bcdefa')
print(str1.translate(table))
# Out:
# bcdefa

# %% [markdown]
# **사용자 입력 함수**
#
# 사용자로 부터 값을 입력 받아서 프로그램이 동작하게 만들기 위한 함수<br>
# 사용자가 입력한 값은 Enter Key를 눌러야 전달 된다.<br>
#
# input() 사용 방법<br>
# 변수이름 = input()<br>
# 변수이름 = input(Message)<br>
# Message : 사용자가 입력해야 하는 값의 힌트를 알려주기 위한 용도로 사용<br>
# Message의 기본 자료형은 string이다.<br>

# %%
# Ex1] 두 정수를 입력 받아 합계를 구하는 code를 작성하세요.
s = 0
a = float(input("첫 번째 수를 입력하세요: "))
b = float(input("두 번째 수를 입력하세요: "))
s = a + b
print("두 수의 합:", s)

s = 0
a = input("첫 번째 수를 입력하세요: ")
b = input("두 번째 수를 입력하세요: ")
s = a + b
print("두 수의 합:", s)
# Out:
# 첫 번째 수를 입력하세요: 10
# 두 번째 수를 입력하세요: 20
# 두 수의 합: 30.0
# 첫 번째 수를 입력하세요: 10
# 두 번째 수를 입력하세요: 20
# 두 수의 합: 1020

# %%
# Ex2] 두 정수를 입력 받아 합,차,평균을 구하는 code를 작성하세요.
a = float(input("첫 번째 수를 입력하세요: "))
b = float(input("두 번째 수를 입력하세요: "))
total = a + b
subtract = a - b
average = (a + b) / 2
print(f'Total: {total} 차이값은 {subtract} 평균값은 {average}')
# Out:
# 첫 번째 수를 입력하세요: 10
# 두 번째 수를 입력하세요: 20
# Total: 30.0 차이값은 -10.0 평균값은 15.0

# %%
# Ex3] 사용자로 부터 값을 입력 받아, 
# 평행 사변형의 면적을 구하는 code를 작성하세요.
# 면적 = 밑변*높이
base = float(input("밑변을 입력하여라: "))
height = float(input("높이를 입력하여라: "))
area = base * height
print("평행 사변형의 면적:", area)
# Out:
# 밑변을 입력하여라: 2.5
# 높이를 입력하여라: 4
# 평행 사변형의 면적: 10.0

# %%
# Ex4] 반지름값을 입력 받아 원의 면적을 구하는 code를 작성하세요.
radius = float(input("반지름값을 입력하여라: "))
area = 3.14159 * radius ** 2
print("원의 면적: ", area)
# Out:
# 반지름값을 입력하여라: 2.5
# 원의 면적:  19.6349375

# %%
# 상품가격을 입력받아 부가세 10% 를 부가한 후의 상품가격을 출력하세요.
VAT = 0.1
price_before_tax = float(input("상품의 세전 가격을 입력하여라: "))
sales_tax = price_before_tax * VAT
price_after_tax = price_before_tax + sales_tax
print("세후 가격:", price_after_tax)

# %%
# 상품가격, 할인율을 입력받아 최종 상품 가격을 출력하세요.
price_before_discount = float(input("상품 가격을 입력하여라: "))
discount = int(input("할인율을 입력하여라(0 - 100): "))
discount_amount = price_before_discount * discount / 100
price_after_discount = price_before_discount - discount_amount
print("최종 상품 가격:", price_after_discount)

# %%
# 상품가격, 할인율입력 받고, 할인이 적용된 상품값에 부가세 10%를 적용한 
# 최종 상품가격을 출력하세요.
VAT = 0.10
price_before_discount = float(input("상품 가격을 입력하여라: "))
discount = int(input("할인율을 입력하여라(0 - 100): "))
discount_amount = price_before_discount * discount / 100
price_after_discount = price_before_discount - discount_amount
sales_tax = price_after_discount * VAT
price_after_tax = price_after_discount + sales_tax
print("최종 상품 가격:", price_after_tax)
# Out:
# 상품 가격을 입력하여라: 150000
# 할인율을 입력하여라(0 - 100): 15
# 최종 상품 가격: 140250.0

# %%
# 정수를 입력 받아 제곱근을 출력하세요.
a = int(input("숫자를 입력하여라: "))
b = a ** 2
print(a, "의 제곱:", b)

# %%
name, age = input('이름 : '), int(input('나이 : '))
print('이름 : {}\n나이 : {}'.format(name, age))

# %%
파이썬 = float(input('파이썬 점수 : '))
C언어 = float(input('C언어 점수 : '))
Java = float(input('Java 점수 : '))
tot = 파이썬 + C언어 + Java
avg = tot / 3
print('합계 : {}\n평균 : {:.2f}'.format(tot, avg))

# %%
# 사용자로부터 이름, 키, 체중 값을 입력 받아 비만도를 구하고
# 출력하는 코드를 작성하시오.
#     비만도 계산 식 : 비만도(%) = 현재 체중 / 표준 체중 * 100
#     표준 체중 계산 식 : 표준 체중 = (현재 키 – 100) * 0.9
#     출력 예제 : 홍길동님의 비만도는 112.15% 입니다.
name = input('이름 : ')
tall = float(input('키(cm) : '))
weight = float(input('체중(kg) : '))
std_weight = (tall - 100) * 0.9
fat_rate = weight / std_weight * 100
print('{}님의 비만도는 {:.2f}% 입니다.'.format(name, fat_rate))

# %%
# 직장인의 연봉을 x 라 하고 연봉의 6%는 국민연금으로, 
# 연봉의 9%는 건강보험으로, 
# 연봉의 1%는 고용보험으로, 
# 연봉의 8%는 퇴직연금으로 계산이 된다고 가정할 때, 
# 월 실수령액은 얼마가 되는지 계산하는 프로그램을 작성하시오. 
# 가능하면 국민연금, 건강보험, 고용보험, 퇴직연금 금액도 사용자가 알 수 있도록 하시오.
연봉 = int(input('연봉 : '))
국민연금, 건강보험, 고용보험, 퇴직연금 = 0.06, 0.09, 0.01, 0.08
 
국민연금_금액 = 연봉 * 국민연금
건강보험_금액 = 연봉 * 건강보험
고용보험_금액 = 연봉 * 고용보험
퇴직연금_금액 = 연봉 * 퇴직연금
 
실수령액 = 연봉 - (국민연금_금액 + 건강보험_금액 + 고용보험_금액 + 퇴직연금_금액)
 
print('연봉 : {:,}'.format(연봉))
print('국민연금 : {:,}'.format(국민연금_금액))
print('건강보험 : {:,}'.format(건강보험_금액))
print('고용보험 : {:,}'.format(고용보험_금액))
print('퇴직연금 : {:,}'.format(퇴직연금_금액))
print('실수령액 : {:,}'.format(실수령액))

# %%
# map() 지정된 함수(예제:int)로 처리해 주는 함수
# a,b = map(int,input().split())
a,b = map(float,input().split())
print(f"{a} * {b} = {a*b}")
print(f"{a} / {b} = {a//b}")
# Out:
# 60 30
# 60.0 * 30.0 = 1800.0
# 60.0 / 30.0 = 2.0

# %%
# 세 개의 정수를 입력 받아서 합계와 평균을 구하세요.
a,b,c = map(int,input("세 개의 정수를 입력해 주세요: ").split())
summary = a+b+c
average = summary / 3
print(summary,average)
# Out:
# 세 개의 정수를 입력해 주세요: 10 20 30
# 60 20.0

# %%
# 정수를 두 개 입력받아서 첫번째 수에는 100을 증가시켜 저장하고, 
# 두 번째 수는 10으로 나눈 나머지를 저장한 후 
# 두 수를 차례로 출력하는 프로그램을 작성하세요.
a,b = map(int,input("Enter two digit ").split())
# 전치증가 a += 100
# 후치증가 a -= 100 
a = a + 100
b = b%10

print(a,b)
# Out:
# Enter two digit 10 20
# -90 0

# %% [markdown]
# **연산자**
#
# 산술 연산자<br>
#  "+"  더하기 연산자<br>
#  "-"  빼기 연산자<br>
#  "*"  곱하기 연산자<br>
#  "/"  나누기 연산자(실수 값)<br>
#  "//" 나누기 연산자(몫)<br>
#  "%"  나누기 연산자(나머지)<br>
#
#
#  **비교 연산자**<br>
#  ==  같다 연산자  반환값은 True, False<br>
#  !=  다르다 연산자  반환값은 True, False<br>
#  ">"   왼쪽 피연산자가 크다 연산자  반환값은 True, False<br>
#  "<"   왼쪽 피연산자가 작다 연산자  반환값은 True, False<br>
#  ">="  왼쪽 피연산자가 크거나 같다  반환값은 True, False<br>
#  "<="  왼쪽 피연산자가 작거나 같다  반환값은 True, False<br>
# "a < b < c" : 비교 연산자를 연결해서 사용 가능<br>
#
#
# **논리 연산자**
# and, or 는 연산자의 앞,뒤의 객체를 반환<br>
# not 은 True, False를 반환<br>
# short circuit적용 이란?
# x and y:x의 값을 구하고 거짓인 경우 x반환, <br>참이면 y값을 구한후 결과 반환<br>
# x or y:x의 값을 구하고 참인 경우 x반환, <br>거짓이면 y값을 구한후 결과 반환<br>

# %%
# print(3 + 5, 3 - 5, 3 * 5, 3 / 5)
# print(15 // 2, 15 % 2)
# print(3 ** 3)

# print(1 == 1, 1 == 2)
# print(1 != 1, 1 != 2)
# print(1 > 1, 1 > 0)
# print(1 < 1, 1 < 0)
# print(1 >= 1, 1 >= 0)
# print(1 <= 1, 1 <= 0)

print (1 and 2) 
print (0 and 1) 
print (1 or 2)
print (0 or 1)
print (0 or 0)
 
print(True and True)
print(True and False)
print(False and True)
print(False and False)
 
print(True or True)
print(True or False)
print(False or True)
print(False or False)
 
print(not True)
print(not False)
# Out:
# 2
# 0
# 1
# 1
# 0
# True
# False
# False
# False
# True
# True
# True
# False
# False
# True

# %% [markdown]
# **식별 연산자**
# 객체를 식별하기 위한 연산자, 동일한 또는 동일하지 않은 객체인지를 식별<br>
#  is      양쪽 객체가 동일하다.  is not  양쪽 객체가 동일하지 않다

# %%
a = 1
b = 2
print(type(a) is type(b))
print(type(a) is int)
print(type(a) is not int)
# Out:
# True
# True
# False

# %% [markdown]
#
# **멤버 연산자**
# 특정 멤버에 지정한 값이 존재하는지 존재하지 않는지 확인하는 연산자<br>
# 값  in/not in  멤버(리스트, 튜플, 사전, 문자열)<br>
# 여러번 반복하여 사용할 경우 프로그램 성능이 낮아질 수 있음<br>
#  in<br>
#  not in

# %%
print(1 in [2, 4, 6, 8, 10])
print(2 in [2, 4, 6, 8, 10])
print(1 not in [2, 4, 6, 8, 10])
print(2 not in [2, 4, 6, 8, 10])
# Out:
# False
# True
# True
# False

# %%
# a 가 짝수인 조건 만들기
a = 10
if a % 2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Even

# %%
# a 가 3의 배수인 조건 만들기
# a를 3로 나누어 0이면 false이고, not이면 True 의미
a = 9
if not a % 3:
    print('3배수')
else:
    print('배수아님')
# Out:
# 3배수

# %%
# a 가 3의 배수인 조건 만들기
# a를 3로 나누어 0이면 false이고, not이면 True 의미
a = 9
if a % 3 != 0:
    print('3배수')
else:
    print('배수아님')
# Out:
# 배수아님

# %% [markdown]
# **랜덤함수**
#  임의의 값을 생성 할 수 있는 함수
#
# 1. random.random() 함수는 0.0에서부터 1.0 사이의 실수(float)를 반환합니다. 정확한 범위는 1.0을 포함하지 않는 범위 입니다. (0.0 <= x < 1.0)

# %%
from random import *
print((random()))

# %%
# 0.0 ~ 10.0 미만 (실수형)
from random import *
print((random() * 10))

# %%
# 0 ~ 10 미만 (정수형)
from random import *
print(int(random() * 10))

# %%
# randrange 함수는 매개변수 1개 버전, 2개 버전이 존재합니다.
# randrange(a, b)는 a <= x < b 의 범위 내에서의 랜덤한 정수(int)를 반환합니다. 
# b를 포함하지 않는 범위입니다.
# randrange(b)는 0 <= x < b 의 범위 내에서의 랜덤한 정수(int)를 반환합니다.  
# b를 포함하지 않습니다!

# 0과 65535 사이의 랜덤 정수를 출력한다.
from random import *
print(randrange(0,63535))
print(randrange(63535))

# -20과 20 사이의 랜덤 정수를 출력한다.
from random import *
print(randrange(-20,21))

# %%
# randint 함수는 인자로 들어온 a, b 사이의 랜덤한 정수(int)를 반환합니다.
# 반환하는 x는  a, b를 포함한 범위 입니다. 
# (a <= N <= b). randrange 함수에 a, b+1을 넣은것과 동일하게 동작합니다.
from random import *
print(randrange(1,3))
print(randint(1,3))

# %%
# random.uniform 함수는 인자로 들어온 a~b 사이의 실수(float)를 반환합니다.
# uniform 함수의 랜덤 범위는 a <= x <= b 입니다.
# 1부터 36.5 사이의 임의의 float
from random import *
print(f'uniform: {uniform(1.0, 36.5)}')

# %%
# 1부터 10 사이의 임의의 짝수(정수), 홀수
from random import *
print(f'짝수: {randrange(0,10,2)}')
print(f'홀수: {randrange(1,10,2)}')
